# %%
# on cherche a determiner le minimum d'une fonction
var('x')
f = x*x - 2*x + 1
u=5
plot(f, -u,u)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
def grad1(f, origine, pas, difference, nbIteration):
    
    g = f.diff(x)
    i = 1
    
    xk = f(x=origine)
    xk1 = xk - pas*g(x=xk)
    L=[xk]
    
    while i != nbIteration and abs(xk - xk1) > difference  :
        L.append(xk1)
        print(i,":",xk)
        xk = xk1
        xk1 = xk - pas*g(x=xk)
        i+=1
    return L

L = grad1(f,2.5,0.1,0.001,100)
# Out:
# 1 : 2.25000000000000
# 2 : 2.00000000000000
# 3 : 1.80000000000000
# 4 : 1.64000000000000
# 5 : 1.51200000000000
# 6 : 1.40960000000000
# 7 : 1.32768000000000
# 8 : 1.26214400000000
# 9 : 1.20971520000000
# 10 : 1.16777216000000
# 11 : 1.13421772800000
# 12 : 1.10737418240000
# 13 : 1.08589934592000
# 14 : 1.06871947673600
# 15 : 1.05497558138880
# 16 : 1.04398046511104
# 17 : 1.03518437208883
# 18 : 1.02814749767107
# 19 : 1.02251799813685
# 20 : 1.01801439850948
# 21 : 1.01441151880759
# 22 : 1.01152921504607
# 23 : 1.00922337203685
# 24 : 1.00737869762948
# 25 : 1.00590295810359

# %%
s = [(i,f(x=i)) for i in L]
u=s[0][0]
plot(f, 0,u,color='indigo') + point(s,pointsize=50,color='mediumseagreen')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
def grad1Dessin(f, origine, pas, difference, nbIteration):
    
    g = f.diff(x)
    i = 1
    
    xk = f(x=origine)
    xk1 = xk - pas*g(x=xk)
    L=[xk]
    
    while i != nbIteration and abs(xk - xk1) > difference  :
        L.append(xk1)
        print(i,":",xk)
        xk = xk1
        xk1 = xk - pas*g(x=xk)
        i+=1
    s = [(i,f(x=i)) for i in L]
    u=s[0][0]
    H = plot(f, 0,u,color='indigo')
    G = point(s,pointsize=50,color='mediumseagreen')
    show(H+G)

# %%
f = x*x - 1/4*x*x*x*x
u=5
plot(f, -u,u)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#recherche de minimum
grad1Dessin(f,1.5,0.1,0.001,100)

#recherche de maximum
grad1Dessin(f,1.5,-0.1,0.001,100)
# Out:
# 1 : 0.984375000000000
# 2 : 0.882885360717773
# 3 : 0.775128015859232
# 4 : 0.666673920855454
# 5 : 0.562969733549689
# 6 : 0.468218263636524
# 7 : 0.384839282291195
# 8 : 0.313570944601210
# 9 : 0.253939996470380
# 10 : 0.204789542494320
# 11 : 0.164690495875501
# 12 : 0.132199086064243
# 13 : 0.105990307884415
# 14 : 0.0849113152403357
# 15 : 0.0679902726685394
# 16 : 0.0544236478430075
# 17 : 0.0435550381966780
# 18 : 0.0348522931281985
# 19 : 0.0278860679490430
# 20 : 0.0223110228713044
# 21 : 0.0178499288990256
# 22 : 0.0142805118535867
# 23 : 0.0114247007096586
# 24 : 0.00913990968724629
# 25 : 0.00731200410272805
# 26 : 0.00584964237610778
# Graphics object consisting of 2 graphics primitives
# 1 : 0.984375000000000
# 2 : 1.08586463928223
# 3 : 1.17500304873617
# 4 : 1.24777895823172
# 5 : 1.30306151441764
# 6 : 1.34241797120240
# 7 : 1.36898630097482
# 8 : 1.38621862244633
# 9 : 1.39708628960759
# 10 : 1.40381324603604
# 11 : 1.40792759387423
# 12 : 1.41042524199594
# Graphics object consisting of 2 graphics primitives

# %%
f = (x*x)/(1+x*x)
u=1
plot(f, -u,u)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#recherche de minimum
grad1Dessin(f,1.5,0.1,0.00001,100)
# Out:
# 1 : 0.692307692307692
# 2 : 0.629034092307692
# 3 : 0.564449332485731
# 4 : 0.499522112452545
# 5 : 0.435534388485101
# 6 : 0.373990536335375
# 7 : 0.316422583882382
# 8 : 0.264133048765274
# 9 : 0.217972077169971
# 10 : 0.178242587293552
# 11 : 0.144755657811300
# 12 : 0.116980724660002
# 13 : 0.0942120002787788
# 14 : 0.0756996855977859
# 15 : 0.0607317853738414
# 16 : 0.0486745350376290
# 17 : 0.0389855927008104
# 18 : 0.0312121215488505
# 19 : 0.0249818421850763
# 20 : 0.0199917043063157
# 21 : 0.0159965575497702
# 22 : 0.0127988827542682
# 23 : 0.0102399446385508
# 24 : 0.00819238513306149
# 25 : 0.00655412801765190
# 26 : 0.00524341502407216
# 27 : 0.00419478968060474
# 28 : 0.00335586126874924
# 29 : 0.00268470413196592
# 30 : 0.00214777104563741
# 31 : 0.00171822079948131
# 32 : 0.00137457866864549
# 33 : 0.00109966397380159
# 34 : 0.000879731710952550
# 35 : 0.000703785641101284
# 36 : 0.000563028652318940
# 37 : 0.000450422993247436
# 38 : 0.000360338431150822
# 39 : 0.000288270763635736
# 40 : 0.000230616620490712
# 41 : 0.000184493301298617
# 42 : 0.000147594643550790
# 43 : 0.000118075716126723
# 44 : 0.0000944605735598575
# 45 : 0.0000755684591850271
# 46 : 0.0000604547675206379
# Graphics object consisting of 3 graphics primitives

# %% [markdown]
# # Fonction avec 2 variables

# %%
var('x','y')
f(x,y) = 1 - 1/(1 + x*x + y*y)
u=-2
plot3d(f, (-u,u), (-u,u))

# %%
def grad2Dessin(f, orgx, orgy, pas, difference, nbIteration):
    
    g = f.gradient()
    i = 1
    
    xyk = f(x=orgx,y=orgy)
    xyk1 = xyk - pas*g(x=xyk[0], y=xyk)
    L=[xyk]
    
    while i != nbIteration and abs(xyk.norm() - xyk1.norm()) > difference  :
        L.append(xyk1)
        print(i,":",xyk)
        xyk = xyk1
        xyk1 = xyk - pas*g(x=xyk[0], y=xyk)
        i+=1
    '''
    s = [(i,f(x=i)) for i in L]
    u=s[0][0]
    H = plot(f, 0,u,color='indigo')
    G = point(s,pointsize=50,color='mediumseagreen')
    show(H+G)
    '''
