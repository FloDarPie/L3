# %%
import sklearn
from sklearn import datasets
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# # Etude de la base de Données

# %%
input_file = "spam.csv"

default = pd.read_csv(input_file)

default.head()
# Out:
#    Unnamed: 0 label                                               text  \
# 0         605   ham  Subject: enron methanol ; meter # : 988291\r\n...
# 1        2349   ham  Subject: hpl nom for january 9 , 2001\r\n( see...
# 2        3624   ham  Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3        4685  spam  Subject: photoshop , windows , office . cheap ...
# 4        2030   ham  Subject: re : indian springs\r\nthis deal is t...
#
#    label_num
# 0          0
# 1          0
# 2          0
# 3          1
# 4          0

# %%
#nettoyage
#base_clean = default.dropna()

# %%
A = default.iloc[0]

# %%
print(A[2])
# Out:
# Subject: enron methanol ; meter # : 988291
# this is a follow up to the note i gave you on monday , 4 / 3 / 00 { preliminary
# flow data provided by daren } .
# please override pop ' s daily volume { presently zero } to reflect daily
# activity you can obtain from gas control .
# this change is needed asap for economics purposes .

# %%
print(A[2].split(" "))
# Out:
# ['Subject:', 'enron', 'methanol', ';', 'meter', '#', ':', '988291\r\nthis', 'is', 'a', 'follow', 'up', 'to', 'the', 'note', 'i', 'gave', 'you', 'on', 'monday', ',', '4', '/', '3', '/', '00', '{', 'preliminary\r\nflow', 'data', 'provided', 'by', 'daren', '}', '.\r\nplease', 'override', 'pop', "'", 's', 'daily', 'volume', '{', 'presently', 'zero', '}', 'to', 'reflect', 'daily\r\nactivity', 'you', 'can', 'obtain', 'from', 'gas', 'control', '.\r\nthis', 'change', 'is', 'needed', 'asap', 'for', 'economics', 'purposes', '.']

# %%
cpt_ham = 0
cpt_spam = 0

maxi = 0
maxi2 = 10000

for i in range (default.size // 4):
    t = data.iloc[i]
    
    if t[3] == 0:
        
        if maxi < t[0]:
            maxi = t[0]
        cpt_ham+=1
    else:
                
        if maxi2 > t[0]:
            maxi2 = t[0]
        #print(t[0])
        cpt_spam+=1
    
print(maxi) 
print(maxi2)
# Out:
# 3671
# 3672

# %%
print(cpt_ham)
print(cpt_spam)
# Out:
# 3672
# 1499

# %%
x = ['ham','spam']
y = [cpt_ham,cpt_spam]

plt.bar(x,y, width = 0.6)
plt.show()

# %% [markdown]
# # Analyse des mots

# %%
import re

dict_mot_spam = dict()

for i in range (default.size // 4):
    
    #check if spam
    if default.iloc[i][3] == 1:
        #retire les points, virgules, et autres caracteres de mise en page
        mot = re.findall(r"[\w]+",default.iloc[i][2])
        for w in mot:
            value = dict_mot_spam.get(w, None)
            if value is not None: 
                dict_mot_spam[w] = value+1
            else:
                dict_mot_spam[w] = 1

# %%
print(dict_mot_spam)
# Out:
# {'Subject': 1498, 'photoshop': 79, 'windows': 206, 'office': 180, 'cheap': 78, 'main': 15, 'trending': 1, 'abasements': 0, 'darer': 0, 'prudently': 0, 'fortuitous': 1, 'undergone': 0, 'lighthearted': 0, 'charm': 0, 'orinoco': 0, 'taster': 0, 'railroad': 2, 'affluent': 1, 'pornographic': 0, 'cuvier': 0, 'irvin': 0, 'parkhouse': 0, 'blameworthy': 0, 'chlorophyll': 0, 'robed': 0, 'diagrammatic': 1, 'fogarty': 0, 'clears': 0, 'bayda': 1, 'inconveniencing': 0, 'managing': 6, 'represented': 0, 'smartness': 0, 'hashish': 1, 'academies': 0, 'shareholders': 17, 'unload': 0, 'badness': 0, 'danielson': 0, 'pure': 3, 'caffein': 0, 'spaniard': 2, 'chargeable': 1, 'levin': 0, 'looking': 253, 'for': 2522, 'medication': 33, 'we': 1137, 're': 230, 'the': 7253, 'best': 253, 'source': 70, 'it': 1087, 'is': 2255, 'difficult': 7, 'to': 5159, 'make': 192, 'our': 1034, 'material': 87, 'condition': 12, 'better': 87, 'by': 667, 'law': 19, 'but': 304, 'easy': 98, 'enough': 33, 'ruin': 2, 'bad': 36, 'laws': 11
# ...
